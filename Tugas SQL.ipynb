# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
#  1. Prepare a list of offices sorted by country, state, city.

# %%
run("SELECT * FROM offices ORDER BY country, state, city ")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# 2. How many employees are there in the company?

# %%
run("SELECT COUNT(*) AS totalEmployees FROM employees")
# Out:
#    totalEmployees
# 0              23

# %% [markdown]
# 3. What is the total of payments received?

# %%
run("SELECT SUM(amount) AS totalPayments FROM payments")
# Out:
#    totalPayments
# 0     8853839.23

# %% [markdown]
# 4. List the product lines that contain 'Cars'

# %%
run("SELECT productLine FROM productLines WHERE productLine LIKE '%Cars'")
# Out:
#     productLine
# 0  Classic Cars
# 1  Vintage Cars

# %% [markdown]
# 5. Report total payments for October 28, 2004

# %%
run("SELECT paymentDate, SUM(amount) AS totalPayments FROM payments GROUP BY paymentDate HAVING paymentDate ='2004-10-28'")
# Out:
#   paymentDate  totalPayments
# 0  2004-10-28       47411.33

# %% [markdown]
# 6. Report those payments greater than \$100,000.

# %%
run ("SELECT * FROM payments WHERE amount>100000 ORDER BY amount")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             148    KM172879  2003-12-26  105743.00
# 2             124    KI131716  2003-08-15  111654.40
# 3             141     ID10962  2004-12-31  116208.40
# 4             141    JE105477  2005-03-18  120166.58

# %% [markdown]
# 7. List the products in each product line.

# %%
run ("SELECT productLine, productCode, productName FROM products ORDER BY productLine")
# Out:
#           productLine productCode                                  productName
# 0        Classic Cars    S10_1949                     1952 Alpine Renault 1300
# 1        Classic Cars    S10_4757                          1972 Alfa Romeo GTA
# 2        Classic Cars    S10_4962                       1962 LanciaA Delta 16V
# 3        Classic Cars    S12_1099                            1968 Ford Mustang
# 4        Classic Cars    S12_1108                            2001 Ferrari Enzo
# 5        Classic Cars    S12_3148                           1969 Corvair Monza
# 6        Classic Cars    S12_3380                           1968 Dodge Charger
# 7        Classic Cars    S12_3891                             1969 Ford Falcon
# 8        Classic Cars    S12_3990                      1970 Plymouth Hemi Cuda
# 9        Classic Cars    S12_4675                           1969 Dodge Charger
# 10       Classic Cars    S18_1129                              1993 Mazda RX-7
# ...

# %% [markdown]
# 8. How many products in each product line?

# %%
run("SELECT productLine, COUNT(*) AS TotalProduct FROM products GROUP BY productLine")
# Out:
#         productLine  TotalProduct
# 0      Classic Cars            38
# 1       Motorcycles            13
# 2            Planes            12
# 3             Ships             9
# 4            Trains             3
# 5  Trucks and Buses            11
# 6      Vintage Cars            24

# %% [markdown]
# 9. What is the minimum payment received?

# %%
run ("SELECT MIN(amount) AS MinimumPayment FROM payments")
# Out:
#    MinimumPayment
# 0          615.45

# %% [markdown]
# 10. List all payments greater than twice the average payment.

# %%
run ("""SELECT * FROM payments WHERE amount > 
        2*(SELECT AVG(amount) FROM payments)
    """)
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run ("SELECT AVG(((MSRP-buyPrice)/buyPrice)*100) AS averagePercentageMarkup FROM products")
# Out:
#    averagePercentageMarkup
# 0                88.702392

# %% [markdown]
# 12. How many distinct products does ClassicModels sell?

# %%
run("SELECT COUNT(DISTINCT productCode) AS DistinctProduct FROM products")
# Out:
#    DistinctProduct
# 0              110

# %% [markdown]
# 13. Report the name and city of customers who don't have sales representatives?

# %%
run ("SELECT customerName, city FROM customers WHERE salesRepEmployeeNumber IS null")
# Out:
#                       customerName              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# ...

# %% [markdown]
# 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run ("SELECT CONCAT (firstName, ' ', lastName) AS Full_Name, jobTitle AS Job_Title FROM employees WHERE jobTitle LIKE 'VP%' OR jobTitle LIKE '%Manager%'")
# Out:
#            Full_Name             Job_Title
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# 15. Which orders have a value greater than $5,000?

# %%
run ("SELECT orderNumber, SUM(quantityOrdered * priceEach) AS Value FROM orderDetails GROUP BY orderNumber HAVING Value > 5000 ORDER BY Value")
# Out:
#      orderNumber     Value
# 0          10102   5494.78
# 1          10216   5759.42
# 2          10422   5849.44
# 3          10290   5858.56
# 4          10236   5899.38
# 5          10130   6036.96
# 6          10298   6066.78
# 7          10243   6276.60
# 8          10269   6419.84
# 9          10335   6466.44
# 10         10146   6631.36
# 11         10233   7178.66
# 12         10213   7310.42
# 13         10323   7466.32
# 14         10125   7565.08
# 15         10218   7612.06
# 16         10421   7639.10
# 17         10112   7674.94
# 18         10199   7678.25
# 19         10365   8307.28
# 20         10423   8597.73
# 21         10392   8807.12
# 22         10265   9415.13
# 23         10352   9658.74
# 24         10152   9821.32
# 25         10166   9977.85
# 26         10100  10223.83
# 27         10101  10549.01
# 28         10190  10721.86
# 29         10415  10945.26
# ..           ...       ...
# 273        10122  50824.66
# 274        10108  51001.22
# ...
